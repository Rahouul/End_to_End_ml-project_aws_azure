# %%
#Importing Data and required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from catboost import CatBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# %%
#Read the dataset
df = pd.read_csv('/home/Rahul/Desktop/End_to_End_ML_Projects/Notebook/Data/StudentsPerformance.csv')

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Preparing the variables (X,y) here prediction is math score
X = df.drop(columns = 'math score', axis =1)
y = df['math score']

# %%
X.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  reading score  writing score
# 0                    none             72             74
# 1               completed             90             88
# 2                    none             95             93
# 3                    none             57             44
# 4                    none             78             75

# %%
y.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
# Creation of Column transformer for transforming num_feature in lower(standard values) and categroical with lables
num_features = X.select_dtypes(exclude = 'object').columns
cat_features = X.select_dtypes(include = 'object').columns

num_transformer = StandardScaler()
cat_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ('OneHotEncoder', cat_transformer, cat_features,),
        ('StandardScaler', num_transformer, num_features)
    ]
)

# %%
print(cat_features)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
#Train test split of data for model training
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 45)

# %%
#Transform the data with the help of the preprocessor
X_train_scaled= preprocessor.fit_transform(X_train)
X_test_scaled= preprocessor.transform(X_test)

# %%
#Creation of evaluation function for all metrics
def evaluate_model(true, predicted):
    #r2_score = r2_score(true, predicted), 
    mse = mean_squared_error(true, predicted), 
    mae = mean_absolute_error(true, predicted), 
    rmse = root_mean_squared_error(true, predicted)
    return  mse, mae, rmse

# %%
#For testing all regression model in one code create a dictionary of models 
model = {
    "linear regressor" : LinearRegression(),
    "lasso" : Lasso() ,
    'Ridge': Ridge() ,
    'K-Neighbours regressor': KNeighborsRegressor(),
    'Decision Tree': DecisionTreeRegressor(),
    'XGBReressor': XGBRegressor(),
    'CatBoosting regressor': CatBoostRegressor(verbose = False),
    'AdaBoost regressor': AdaBoostRegressor(),           
    "Random_forest" : RandomForestRegressor(),    
}

model_list = []
rmse_list = []
for name, model in model.items():
    model.fit(X_train_scaled, y_train)
    
    #Make prediction
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)
    
    #Evaluate the train and test dataset
    
    model_train_mse, model_train_mae, model_train_rmse = evaluate_model(y_train, y_train_pred)
    model_test_mse, model_test_mae, model_test_rmse = evaluate_model(y_test, y_test_pred)

    print(f"Model: {name}")
    model_list.append(name)
          

    print('Model performance on training dataset')
    #print('-R2_score : {:.4f}'.format(model_train_r2_score))
    print('-Mean squared error: ' , {model_train_mse})
    print('-Mean Absolute error: ', {model_train_mae})
    print('-Root Mean Squared Error:', {model_train_rmse})

    print('-------------------------------------------------------------')
    
    print('Model performance on test dataset')
    #print('-R2_score : {:.4f}'.format(model_test_r2_score))
    print('-Mean squared error:' , {model_test_mse})
    print('-Mean Absolute error: ', {model_test_mae})
    print('-Root Mean Squared Error:', {model_test_rmse})
    rmse_list.append(model_test_rmse)


    print('+' * 35)
    print('+' * 35)
# Out:
# Model: linear regressor
# Model performance on training dataset
# -Mean squared error:  {(28.218672956006717,)}
# -Mean Absolute error:  {(4.215589211261674,)}
# -Root Mean Squared Error: {5.3121250885127616}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(29.314085103916,)}
# -Mean Absolute error:  {(4.371625150159658,)}
# -Root Mean Squared Error: {5.414248341544374}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: lasso
# Model performance on training dataset
# -Mean squared error:  {(42.94281017112817,)}
# -Mean Absolute error:  {(5.14503259980304,)}
# -Root Mean Squared Error: {6.553076389843794}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(41.884374140733165,)}
# -Mean Absolute error:  {(5.2444099442945795,)}
# -Root Mean Squared Error: {6.471813821544402}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: Ridge
# Model performance on training dataset
# -Mean squared error:  {(28.221194944724147,)}
# -Mean Absolute error:  {(4.21414938743898,)}
# -Root Mean Squared Error: {5.3123624636054485}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(29.296035426186645,)}
# -Mean Absolute error:  {(4.371820876279466,)}
# -Root Mean Squared Error: {5.412581216590348}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: K-Neighbours regressor
# Model performance on training dataset
# -Mean squared error:  {(33.9022,)}
# -Mean Absolute error:  {(4.5955,)}
# -Root Mean Squared Error: {5.822559574620083}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(47.68459999999999,)}
# -Mean Absolute error:  {(5.619,)}
# -Root Mean Squared Error: {6.905403681176068}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: Decision Tree
# Model performance on training dataset
# -Mean squared error:  {(0.140625,)}
# -Mean Absolute error:  {(0.02625,)}
# -Root Mean Squared Error: {0.375}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(72.285,)}
# -Mean Absolute error:  {(7.025,)}
# -Root Mean Squared Error: {8.502058574251297}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: XGBReressor
# Model performance on training dataset
# -Mean squared error:  {(0.8478277026020336,)}
# -Mean Absolute error:  {(0.6032596767693758,)}
# -Root Mean Squared Error: {0.9207755983962833}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(42.860829579194416,)}
# -Mean Absolute error:  {(5.218496084213257,)}
# -Root Mean Squared Error: {6.546818279072241}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: CatBoosting regressor
# Model performance on training dataset
# -Mean squared error:  {(8.863862532397684,)}
# -Mean Absolute error:  {(2.3335659829522926,)}
# -Root Mean Squared Error: {2.9772239640977105}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(36.293041537089415,)}
# -Mean Absolute error:  {(4.8234865923722685,)}
# -Root Mean Squared Error: {6.024370634106887}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: AdaBoost regressor
# Model performance on training dataset
# -Mean squared error:  {(33.37084653597384,)}
# -Mean Absolute error:  {(4.707566062489123,)}
# -Root Mean Squared Error: {5.7767505170271845}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(38.99039013449799,)}
# -Mean Absolute error:  {(5.023852039513091,)}
# -Root Mean Squared Error: {6.244228545985324}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++
# Model: Random_forest
# Model performance on training dataset
# -Mean squared error:  {(5.041535767291667,)}
# -Mean Absolute error:  {(1.7799275,)}
# -Root Mean Squared Error: {2.2453364485732794}
# -------------------------------------------------------------
# Model performance on test dataset
# -Mean squared error: {(38.313624710000006,)}
# -Mean Absolute error:  {(5.0295000000000005,)}
# -Root Mean Squared Error: {6.189800054121297}
# +++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++

# %%
pd.DataFrame(list(zip(model_list, rmse_list)),columns = ['Model Name', 'RMSE_Score']).sort_values(by = ['RMSE_Score'], ascending = False)
# Out:
#                Model Name  RMSE_Score
# 4           Decision Tree    8.502059
# 3  K-Neighbours regressor    6.905404
# 5             XGBReressor    6.546818
# 1                   lasso    6.471814
# 7      AdaBoost regressor    6.244229
# 8           Random_forest    6.189800
# 6   CatBoosting regressor    6.024371
# 0        linear regressor    5.414248
# 2                   Ridge    5.412581

# %%
pd.DataFrame({'Actual Value' : y_test, 'Predicted Value':y_test_pred, 'Difference': y_test-y_test_pred})
# Out:
#      Actual Value  Predicted Value  Difference
# 726            65        65.700000   -0.700000
# 243            59        56.090000    2.910000
# 342            69        63.680000    5.320000
# 976            60        63.760000   -3.760000
# 919            91        94.670000   -3.670000
# ..            ...              ...         ...
# 458           100        97.163333    2.836667
# 169            67        55.940000   11.060000
# 297            71        78.060000   -7.060000
# 10             58        56.680000    1.320000
# 212            42        49.460000   -7.460000
#
# [200 rows x 3 columns]
