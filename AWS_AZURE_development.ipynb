# %%
#END TO END PROJECT FOR AWS AND AZURE

# %%
"""# DAY 1:
1. SET UP THE GITHUB {REPOSITORY} WHEN YOU WORKING WITH THE TEAM 
    a) set up new environment #before implenting the project 
        (a) (conda create -p venv python==3.8  -y) in folder where prject is developed
        (b) (activate venv/) to activate environment

    #CLONE THIS ENTIRE REPOSITORY AND SYNC WITH THE GITHUB
    (git init) # intializing the repository (folder)
    Create a Read.md file in workig folder #this is for tracking the project development text file\
    (git add README.md) # Add this in github repository

    (git commit -m "first commit") #for commiting 

    (git status)  # for checking status till now 

    #push this file into my GIt repository
        git branch -M main
        git remote add origin https://github.com/Rahouul/End_to_End_ml-project_aws_azure.git
        git remote -v # to see that sync or not 
        git push -u origin main

        #if you first time  search for (git gloabl config) and copy the commands for registration
    
        git push -u origin main #push origin to main 

    #Create a gitignore file in github by clicking newfile (.gitignore)
            A.gitignore file is used to tell Git which files and directories to explicitly ignore from version control.
        It helps keep your repository clean, efficient, and secure by ensuring that unnecessary, temporary, or sensitive
        files are not accidentally committed and shared with other
    
    b) setup.py (Building our applications as packages)
        setup.py is a module used to build and distribute Python packages. It typically contains information about the package, such as 
        its name, version, and dependencies, as well as instructions for building and installing the package.

    #src folder is created to project in that folder that separate other files from my project
        an __init__.py file was mandatory for Python to treat a directory as a package.
        a collection of module that can be imported as a single unit. 
        

        
    c) requirements.py #This file contain the files needed for the project
"""

# %%
"""
DAY2: Project structure, logging and Exception Handling

In src:
    1. create a folder components: all the module are in this foler from data ingestion -- model training that use in  project.
    
        create an __init__.py file file was mandatory for Python to treat a directory as a package.
                                a collection of module that can be imported as a single unit.
        create data_ingestion.py:  a component file responsible for the first step of a data pipeline: loading raw data from its
                                   source and preparing it for analysis or modeling. 
                                   Data Extraction, Data Ingestion/Loading, Data Splitting, Data Saving

        create data_transformation.py: a Python script dedicated to cleaning, preprocessing, and restructuring raw data into a clean, 
                                        standardized format suitable for analysis, visualization, or machine learning model
                                        Data Cleaning, Data Formatting/Structuring, Feature Engineering, Preprocessing for ML, 
                                        Transformation Pipeline
                                        

        create model_trainer.py: Trains the model on the transformed data

    2. create a folder pipeline 
    
        __init__.py:  file file was mandatory for Python to treat a directory as a package.
                                a collection of module that can be imported as a single unit.
    
        train_pipeline.py :  file is a Python script commonly used in machine learning projects to orchestrate the end-to-end process of
                                    training a model. It typically automates data preprocessing, model training, evaluation, and saving,
                                    often serving as a central component in an MLOps workflow. 
                                    
        predict_pipeline.py : is a Python script commonly used in machine learning projects to handle inference—taking new, raw user input, 
                            processing it, and generating predictions using a previously trained model. It acts as a bridge between a web 
                            application interface (like Flask or Streamlit) and the trained model artifacts (.pkl files
        
        
        

    3. createe logger.py:  a common filename for Python scripts that use the built-in logging module to record events, errors, and debugging
                            information while a program runs. This module provides a flexible framework for tracking application 
                            and diagnosing problem.

                            

    4. create exception.py: is a specialized function within Python's built-in logging module used within except blocks to log error 
                            messages along with the full stack trace. It is specifically designed to aid in debugging by providing context 
                            on where and why an error occurred. 


    5. utlis.py: is a common Python file used to store helper functions, classes, or constants that are reused across different parts of a 
                project. 


    #Write code on exception.py for exception handling. 



"""
